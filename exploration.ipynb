# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
import matplotlib.pyplot as pyplot
import seaborn as sns
import ast, json
import glob
import csv

# %% [markdown]
# Loading the Data

# %%
data = pd.read_csv("2000.csv")

# %% [markdown]
# Exploratory Data Analysis

# %%
print('Number of rows:' , data.shape[0])
print('Number of columns:' , data.shape[1])
# Out:
# Number of rows: 5683047
# Number of columns: 29

# %%
data.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2000      1          28          5   1647.0        1647   1906.0
# 1  2000      1          29          6   1648.0        1647   1939.0
# 2  2000      1          30          7      NaN        1647      NaN
# 3  2000      1          31          1   1645.0        1647   1852.0
# 4  2000      1           1          6    842.0         846   1057.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1859            HP        154  ...     15       11          0
# 1        1859            HP        154  ...      5       47          0
# 2        1859            HP        154  ...      0        0          1
# 3        1859            HP        154  ...      7       14          0
# 4        1101            HP        609  ...      3        8          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
data.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  5683047.0  5.683047e+06  5.683047e+06  5.683047e+06  5.495557e+06
# mean      2000.0  6.534263e+00  1.576453e+01  3.955945e+00  1.356324e+03
# std          0.0  3.441708e+00  8.792426e+00  1.992334e+00  4.923077e+02
# min       2000.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2000.0  4.000000e+00  8.000000e+00  2.000000e+00  9.290000e+02
# 50%       2000.0  7.000000e+00  1.600000e+01  4.000000e+00  1.339000e+03
# 75%       2000.0  1.000000e+01  2.300000e+01  6.000000e+00  1.750000e+03
# max       2000.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  5.683047e+06  5.481303e+06  5.683047e+06  5.683047e+06
# mean   1.346648e+03  1.487695e+03  1.500130e+03  1.140978e+03
# std    4.805208e+02  5.265580e+02  5.041544e+02  8.420707e+02
# ...

# %%
#Datatypes
data.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn                 int64
# TaxiOut                int64
# Cancelled              int64
# CancellationCode     float64
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %% [markdown]
# Preprocessing

# %%
#Checking for missing Values
data.isnull().values.any()
# Out:
# True

# %%
print('Number of missing values in each column')
missing = data.isnull().sum().to_frame().rename(columns={0:'n_missing_values'})
missing
# Out:
# Number of missing values in each column
#                    n_missing_values
# Year                              0
# Month                             0
# DayofMonth                        0
# DayOfWeek                         0
# DepTime                      187490
# CRSDepTime                        0
# ArrTime                      201744
# CRSArrTime                        0
# UniqueCarrier                     0
# FlightNum                         0
# TailNum                           0
# ActualElapsedTime            201744
# CRSElapsedTime                  269
# AirTime                      201744
# ArrDelay                     201744
# DepDelay                     187490
# Origin                            0
# Dest                              0
# Distance                          0
# TaxiIn                            0
# TaxiOut                           0
# Cancelled                         0
# CancellationCode            5683047
# Diverted                          0
# ...

# %%
#Drop the rows with missing values 
data = data.dropna(axis = 0)
data.isnull().values.any()
# Out:
# False

# %%
#eliminating cancelled flights 
data = data[data.Cancelled != 1]

# %%
#removing forbidden variables and other with no useful information 
data = data.drop(['ArrTime', 'AirTime', 'ActualElapsedTime', 'TaxiIn', 'Diverted', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'UniqueCarrier', 'FlightNum', 'TailNum', 'Cancelled', 'CancellationCode'], axis =1)
data.head(5)
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, CRSArrTime, CRSElapsedTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiOut]
# Index: []

# %%
#Encoding the categorical variables
data["Origin"]= data["Origin"].astype('category')
data["Origin"]= data["Origin"].cat.codes
data["Dest"]= data["Dest"].astype('category')
data["Dest"]= data["Dest"].cat.codes
data.dtypes
data.head(15)
# Out:
# Empty DataFrame
# Columns: [Year, Month, DayofMonth, DayOfWeek, DepTime, CRSDepTime, CRSArrTime, CRSElapsedTime, ArrDelay, DepDelay, Origin, Dest, Distance, TaxiOut]
# Index: []

# %% [markdown]
# Analysis

# %%
# analysis of the correlation matrix for numerical variables
data_numerical = data_droped.drop(['Origin', 'Dest'], axis = 1)
corr = data_numerical.corr(method = 'pearson')
corr.head(5)
# Out:
#             Year     Month  DayofMonth  DayOfWeek   DepTime  CRSDepTime  \
# Year         NaN       NaN         NaN        NaN       NaN         NaN
# Month        NaN  1.000000    0.004870   0.009847  0.000266   -0.002835
# DayofMonth   NaN  0.004870    1.000000  -0.009445  0.001460   -0.000994
# DayOfWeek    NaN  0.009847   -0.009445   1.000000  0.004671    0.003515
# DepTime      NaN  0.000266    0.001460   0.004671  1.000000    0.958367
#
#             CRSArrTime  CRSElapsedTime  ArrDelay  DepDelay  Distance   TaxiOut
# Year               NaN             NaN       NaN       NaN       NaN       NaN
# Month        -0.003949        0.007816  0.031446  0.030691  0.007975  0.018286
# DayofMonth   -0.001242        0.001011  0.033926  0.032722  0.000952  0.010377
# DayOfWeek     0.006982        0.013658  0.021982  0.031830  0.013420 -0.008535
# DepTime       0.729749       -0.026102  0.172275  0.183271 -0.030289  0.057354

# %%
#plotting the correlation matrix 
f, ax = plt.pyplot.subplots(figsize=(12, 9))
cmap = sns.diverging_palette(250, 10, as_cmap=True)
sns.heatmap(corr, annot=True, vmin = -0.6 , vmax=0.5, cmap = cmap)
# Out:
# <AxesSubplot: >
